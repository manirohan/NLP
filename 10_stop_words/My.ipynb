# %%
import spacy

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
nlp = spacy.load('en_core_web_sm')
doc= nlp('I want to go to marse and settle there and do agriculture for my future generations')

for token in doc:
    if token.is_stop:
        print(token)
# Out:
# I
# to
# go
# to
# and
# there
# and
# do
# for
# my

# %%
def preprocess(text):
    doc = nlp(text)
    no_stop_words = [token.text for token in doc if not token.is_stop and not token.is_punct]

    return ' '.join(no_stop_words)

# %%
preprocess('Musk wants time to prepare for a trial over his')
# Out:
# 'Musk wants time prepare trial'

# %%
import pandas as pd

# %%
df = pd.read_json('doj_press.json',lines=True)
df.shape
# Out:
# (13087, 6)

# %%
df.head()
# Out:
#         id                                              title  \
# 0     None       Convicted Bomb Plotter Sentenced to 30 Years
# 1  12-919   $1 Million in Restitution Payments Announced t...
# 2  11-1002  $1 Million Settlement Reached for Natural Reso...
# 3   10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4   18-898  $100 Million Settlement Will Speed Cleanup Wor...
#
#                                             contents  \
# 0  PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# 1    WASHINGTON – North Carolina’s Waccamaw River...
# 2        BOSTON– A $1-million settlement has been...
# 3    WASHINGTON—A federal grand jury in Las Vegas...
# 4  The U.S. Department of Justice, the U.S. Envir...
#
#                         date         topics  \
# 0  2014-10-01T00:00:00-04:00             []
# 1  2012-07-25T00:00:00-04:00             []
# 2  2011-08-03T00:00:00-04:00             []
# 3  2010-01-08T00:00:00-05:00             []
# ...

# %%
df.describe()
# Out:
#             id                                              title  \
# count    12810                                              13087
# unique   12672                                              12887
# top     13-526  Northern California Real Estate Investor Agree...
# freq         3                                                  8
#
#                                                  contents  \
# count                                               13087
# unique                                              13080
# top       WASHINGTON – ING Bank N.V., a financial inst...
# freq                                                    2
#
#                              date topics           components
# count                       13087  13087                13087
# unique                       2400    253                  810
# top     2018-04-13T00:00:00-04:00     []  [Criminal Division]
# freq                           20   8399                 2680

# %%
type(df['topics'][0])
# Out:
# list

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13087 entries, 0 to 13086
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          12810 non-null  object
#  1   title       13087 non-null  object
#  2   contents    13087 non-null  object
#  3   date        13087 non-null  object
#  4   topics      13087 non-null  object
#  5   components  13087 non-null  object
# dtypes: object(6)
# memory usage: 613.6+ KB

# %%
df.columns
# Out:
# Index(['id', 'title', 'contents', 'date', 'topics', 'components'], dtype='object')

# %%
df[df['topics'].str.len()!=0].iloc[0]['components']
# Out:
# ['Environment and Natural Resources Division']

# %%
df.shape
# Out:
# (13087, 6)

# %%
df = df.head(100)
df
# Out:
#          id                                              title  \
# 0      None       Convicted Bomb Plotter Sentenced to 30 Years
# 1   12-919   $1 Million in Restitution Payments Announced t...
# 2   11-1002  $1 Million Settlement Reached for Natural Reso...
# 3    10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4    18-898  $100 Million Settlement Will Speed Cleanup Wor...
# ..      ...                                                ...
# 95   15-914  After Nearly 20 Years, International Fugitive ...
# 96  14-1142  After Supreme Court Declines to Hear Same-Sex ...
# 97   16-731  After UBS Produces Singapore-Based Documents, ...
# 98  09-1056  AGCO Corp. to Pay $1.6 Million in Connection w...
# 99   10-872  Agency Chief FOIA Officers Respond to the Pres...
#
#                                              contents  \
# 0   PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# 1     WASHINGTON – North Carolina’s Waccamaw River...
# ...

# %%
df['words'] = df['contents'].apply(preprocess)

# %%
df.head().iloc[0]['contents'][:400]
# Out:
# 'PORTLAND, Oregon. – Mohamed Osman Mohamud, 23, who was convicted in 2013 of attempting to use a weapon of mass destruction (explosives) in connection with a plot to detonate a vehicle bomb at an annual Christmas tree lighting ceremony in Portland, was sentenced today to serve 30 years in prison, followed by a lifetime term of supervised release. Mohamud, a naturalized U.S. citizen from Somalia and'

# %%
df.head().iloc[0]['words'][:200]
# Out:
# 'PORTLAND Oregon Mohamed Osman Mohamud 23 convicted 2013 attempting use weapon mass destruction explosives connection plot detonate vehicle bomb annual Christmas tree lighting ceremony Portland sentenc'
